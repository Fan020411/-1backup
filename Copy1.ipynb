# %% [markdown]
# # Comm 493 Time Series Analysis  -- Xinlan Yang
#
# # Company Context
#
# Name and Location
#
# Presotea,  346 Princess St., Kingston, ON K7L 1B6
#
# # High-level Description of the Business
#
# Presotea is located in the central area of Kingston, Canada, a region known for its close-knit business community and clustering enterprises within the downtown core. Positioned as one of the prominent bubble tea establishments in the area, Presotea proudly operates its branch in Kingston, offering economic hand-shaken bubble tea known for its freshness and health benefits. So far, Presotea is one of the emerging players who offer attested beverage experience and brick-and-mortar customer services.
#
# # Business Model and Industry
#
# Presotea's industry falls within the category of food and beverage sector. It pertains to the type of fast-consumption explained by the process of ""order, prepare, pay, and leave"".The fast consumption model Presotea employs does not require large premises; it has limited accessories and space to accommodate all necessary equipment for leisure stays. Such establishments primarily target consumers who prefer takeaway options.
#
#
# # Description of products, services, or Capabilities
#
# Presotea is not just another bubble tea establishment. They serve dedicated tea products, ranging from our signature milk tea and fruit tea to customizable, innovative tea-based beverages prepared by our certified tea masters. Customers have the freedom to choose their preferred sweetness and toppings, including grass jelly, pearl, fruit chunks, boba, and more. Presotea also curates seasonal specials, tailored to trendy products and festive appeals. Their comfortable, contemporary interior is designed to provide a distinctive, high-quality experience, with locally-sourced tea recipes that are sure to delight.
#
# Presotea captures the interest of younger demographics, especially students, who want to enjoy the glamour of bold-flavored and exotic hand-made bubble tea. To cope with e-commerce platforms, Presotea offers online purchasing and delivery. The distribution area is across Kingston and several branches in Montreal.
#
#
#
# # Problem description
#
# Issue Identification: Presotea loses its competitive edge, partially due to the brimming bubble tea industry in Kingston that commences the blow from the Asian perspective of bubble tea sip-on culture and trendiness-cravery which increases competitions. In recent years, Presotea has seen a concerning drop in monthly sales revenue by 23.5% from $65,000 to $49,725 and 15% decline in passenger flow due to some reasons, that all ultimately implores a robust analytic tool.
#
# First, Presotea relies on gut-driven decisions. (Šimek, 2022). They usually make intuitive decisions on specific products, such as stuffed toys and game cards, and keep crafting them. Without knowing which product is underperforming, the store’s fraudulent belief draws back its profitability, and results in an ill-informed value-added chain. Second, Presotea struggles to estimate future performance, which sometimes results in stockpiling or opportunity loss.
# Minotaur does not have an Iaas-focused tool in capturing, analyzing and iterating retrospective data.
# # Impact assessment:
# Excess left-off ingredients increase costs because all materials are perishable, and may result in spoiled food and outmoded products as it takes up capital and refrigerated storage space. Therefore, most order values fall short of the “free delivery” threshold, indicating that customers’ interest is deviating. Also, new customers are difficult to acquire and retain, since competitors like Gong Cha and Chatime yield enduring operations and brand image, resulting in customer churn.
# On the other hand, the absence of forecasting tools results in inferior inventory and timing decisions that result in increased costs and reduced profitability. Consequently, Presotea's reputation among party B may be compromised, thereby constraining its autonomy and efficacy in negotiating with contracted ingredient entities and personnel.
#
# # Solution:
# Presotea decides to adopt DeepAR forecasting algorithm for the purpose of predicting sales volume.This adaptation necessitates the systematic collection and analysis of retrospective data in the bubble tea and cafe industry. This could be divided into several parts.
# 1.Contracting a technical person responsible for the whole “moving to the cloud” process, including building AWS instances, data inspection, environment preparation and building the model.
# 2.To equip refrigeration systems with scanners that measure dynamic stock information and sync real-time data to the model.
# 3.In addition to the technical advancements, Presotea vows to build a structured project management framework, characterized by agile products. As part of this framework, Presotea proposes the development of a dashboard featuring a minimum viable product.This dashboard will serve as a centralized platform for visualizing ongoing tasks and recalibrating trajectories at each stage.
# 4.Moreover, Presotea will develop a marketing plan for this solution in coping with the vast development of machine learning at this store, including a customer pilot program and some supplemental commercial propagations.
#
#
# Solution Description
#
# Business impact and value:
# This initiative involves a comprehensive overhaul of existing prediction formulae to ensure alignment with industry-specific benchmarks and KPIs, particularly inventory management and sales volume. Altering sales volume based on preferences brings auspicious business signs: Presotea can free up resources that manual forecasting procedures would need. No longer constrained by sales volume, employees can concentrate on other facets of the business, such as product innovation which young people always spare a disposition for.
#
# Customer experience:
# A more meticulous prediction model improves Presotea’s compliance with industry standard, which means customers can enjoy a more quality sip of tea. With the algorithm calibrated to cater to customer preferences, Presotea achieves dynamic tuning that consistently aligns with consumer tastes. This approach results in a handpick menu selection that closely mirrors customer preferences, thereby augmenting overall satisfaction levels.
#
# Operational Enhancement: Deep AR helps develop lucid forecasting duties that can eliminate errors that used to be on paperwork and traditional accounting systems.It Reduced errors, setbacks, silos, and redundant work, such as duplicate data entry and discrepancies in reporting in tracking ingredient orders, which concerns the manager, Ela, who know little about Iaas’s logic in forecasting and error-handling.  (Eby, 2018)
#
#
# # Proof of Concept Description
# Business impact and value
# The technical revamping makes Presotea more self-financing, organized and competitive, specifically:
# 1.Streamlining operations to minimize redundant tasks and mitigate errors can significantly bolster revenue and enhance sales margins.
# 2.Aligning predictive models with stakeholders' values should increase their engagement and foster trust of stakeholders in the organization's capabilities.
# 3.Over time, these strategic adjustments enable Presotea to gradually regain market share and fortify its competitive position.
#
# Customer experience:
# Customers will witness the revision and formularization of the cold storage facilities, as well as those exhibited outside, are attached to a real-time panel that syncs stock information, temperature and lead time. This signifies Presotea's integration of database and predictive models, effectively eliminating redundant back-and-forth checks and communications. Customer preferences can be promptly addressed, and each individual obtains their desired milk tea.
#
# Operational enhancement:
# The POC mainly sets up the sagemaker, which transforms the original data into a dataframe, and the Deep AR expedites and erudites the forecasting algorithm. Having adjusted hyperparameters made incremental progression on scalability -- for example, by adjusting prediction_length to control how far future predictions can be made, Presotea streamlines workflow hierarchy and ownership of tasks, which better advance employee’s working pulse and on-leave management. Helen, Amy, Spencer and Holly will enjoy the systematic schedule and task flow assigned, which, in essence, assisted Presotea’s employee adoption and ethical operation.
#
# # Data identification for POC
# The team uses a French bakery’s daily sales as the training input to initiate the environment. Presotea can stimulate its sales pattern by setting up training tasks and configuring endpoints. With the DeepAR algorithm, the team constructs a scalar time series model to forecast Presotea's sales volume in 7 days. This strategic initiative is closely aligned with Presotea's pivotal metrics, notably cost reduction through the optimization of volume formula and increasing sales margins.
# The dataset spans across customers' daily transactions from 2021-01-01 to 2022-09-30, detailing each quantity, unit price, and name. One credential to learning -- sales, can be derived by multiplying price and quantity. Deep AR then ingests the probability distribution in each prediction length, and trains an approximation of this model to predict sales in the target time series. (Amazon Web Service, 2024)
#
# # Key terms
#
# date: date order
#
# time: time order
#
# ticket number: identifier for every single transaction
#
# article: name of the product sold (in French)
#
# quantity: quantity sold
#
# unit_price: price per product

# %% [markdown]
# # Environment Setup and Imports

# %%
# Install or upgrade the numexpr package, which is used by pandas for efficient numerical expressions
# !pip install --upgrade numexpr

# Import necessary libraries from SageMaker for model training and deployment
import sagemaker
from sagemaker import get_execution_role  # Get the IAM role for the SageMaker session
from sagemaker.image_uris import retrieve  # Retrieve the Docker image URI for a specific model
from sagemaker.estimator import Estimator  # Estimator class for model training

# Import boto3 library for interacting with AWS services
import boto3
from botocore.exceptions import ClientError

# Import pandas for data manipulation and analysis
import pandas as pd

# Import json for working with JSON data
import json

# Import matplotlib.pyplot for creating visualizations
import matplotlib.pyplot as plt

# Import seaborn for statistical data visualization
import seaborn as sns
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.1/376.1 kB 16.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.9.0
#     Uninstalling numexpr-2.9.0:
#       Successfully uninstalled numexpr-2.9.0
# ...
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Matplotlib is building the font cache; this may take a moment.

# %%
# Load the Coffee Shop Sales.csv data into a pandas DataFrame
df_coffee = pd.read_csv("Bakery_sales.csv")

# Display the first few rows of the df_coffee DataFrame
print("First few rows of the DataFrame:")
print(df_coffee.head())
# Out:
# First few rows of the DataFrame:
#    Head        date  time  ticket_number               article  Quantity  \
# 0     0  2021-01-02  8:38         150040              BAGUETTE         1
# 1     1  2021-01-02  8:38         150040      PAIN AU CHOCOLAT         3
# 2     4  2021-01-02  9:14         150041      PAIN AU CHOCOLAT         2
# 3     5  2021-01-02  9:14         150041                  PAIN         1
# 4     8  2021-01-02  9:25         150042  TRADITIONAL BAGUETTE         5
#
#    price
# 0   0.90
# 1   1.20
# 2   1.20
# 3   1.15
# 4   1.20

# %%
# Display the number of rows and columns in the df_coffee DataFrame
print("\nShape of the DataFrame (rows, columns):")
print(df_coffee.shape)
# Out:
# Shape of the DataFrame (rows, columns):
# (234005, 7)

# %%
# Drop the specified columns from df_coffee
columns_to_drop = ['ticket_number','Head']
df_coffee.drop(columns=columns_to_drop, inplace=True)

# Display the first few rows of the df_coffee DataFrame
print("First few rows of the DataFrame:")
print(df_coffee.head())
# Out:
# First few rows of the DataFrame:
#          date  time               article  Quantity  price
# 0  2021-01-02  8:38              BAGUETTE         1   0.90
# 1  2021-01-02  8:38      PAIN AU CHOCOLAT         3   1.20
# 2  2021-01-02  9:14      PAIN AU CHOCOLAT         2   1.20
# 3  2021-01-02  9:14                  PAIN         1   1.15
# 4  2021-01-02  9:25  TRADITIONAL BAGUETTE         5   1.20

# %%
# Display summary
print("\nSummary of the DataFrame:")
print(df_coffee.info())
# Out:
# Summary of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234005 entries, 0 to 234004
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      234005 non-null  object
#  1   time      234005 non-null  object
#  2   article   234005 non-null  object
#  3   Quantity  234005 non-null  int64
#  4   price     234005 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 8.9+ MB
# None

# %%
import pandas as pd

# combine date and time
df_coffee['datetime'] = pd.to_datetime(df_coffee['date'] + ' ' + df_coffee['time'])

columns_to_drop = ['date', 'time']
df_coffee.drop(columns=columns_to_drop, inplace=True)
print(df_coffee.head())
# Out:
#                 article  Quantity  price            datetime
# 0              BAGUETTE         1   0.90 2021-01-02 08:38:00
# 1      PAIN AU CHOCOLAT         3   1.20 2021-01-02 08:38:00
# 2      PAIN AU CHOCOLAT         2   1.20 2021-01-02 09:14:00
# 3                  PAIN         1   1.15 2021-01-02 09:14:00
# 4  TRADITIONAL BAGUETTE         5   1.20 2021-01-02 09:25:00

# %%
# Convert the 'InvoiceDate' column to datetime format
df_coffee['datetime'] = pd.to_datetime(df_coffee['datetime'], format='%m/%d/%Y %H:%M')

# Display a concise summary of the df_onlineretail DataFrame to verify the datetime format
print("\nSummary of the DataFrame after converting InvoiceDate to datetime:")
print(df_coffee.info())
# Out:
# Summary of the DataFrame after converting InvoiceDate to datetime:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234005 entries, 0 to 234004
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   article   234005 non-null  object
#  1   Quantity  234005 non-null  int64
#  2   price     234005 non-null  float64
#  3   datetime  234005 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 7.1+ MB
# None

# %%
# Calculate the number of missing values in each column
missing_values = df_coffee.isnull().sum()

# Print the number of missing values for each column
print("\nMissing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# article     0
# Quantity    0
# price       0
# datetime    0
# dtype: int64

# %%
# Filter out rows with negative prices or quantities
negative_prices = df_coffee[df_coffee['price'] < 0]
negative_quantities = df_coffee[df_coffee['Quantity'] < 0]

# Print rows with negative prices
if not negative_prices.empty:
    print("\nRows with negative Prices:")
    print(negative_prices)
else:
    print("\nThere are no negative Prices.")

# Print rows with negative quantities
if not negative_quantities.empty:
    print("\nRows with negative Quantities:")
    print(negative_quantities)
else:
    print("\nThere are no negative quantities.")
# Out:
# There are no negative Prices.
#
# Rows with negative Quantities:
#                      article  Quantity  price            datetime
# 448                 BAGUETTE        -1   0.90 2021-01-03 10:41:00
# 1162           SPECIAL BREAD        -1   2.40 2021-01-05 19:00:00
# 1163       DIVERS PATISSERIE        -1   6.00 2021-01-05 19:00:00
# 1164      DIVERS BOULANGERIE        -1   2.00 2021-01-05 19:00:00
# 1467                   COUPE        -1   0.15 2021-01-08 11:58:00
# ...                      ...       ...    ...                 ...
# 233054                 COUPE        -2   0.15 2022-09-27 18:03:00
# 233055  TRADITIONAL BAGUETTE        -1   1.30 2022-09-27 18:03:00
# 233056       CEREAL BAGUETTE        -3   1.35 2022-09-27 18:03:00
# 233553          BOISSON 33CL        -1   1.50 2022-09-29 11:55:00
# 233554            PLAT 7.60E        -1   7.60 2022-09-29 11:55:00
#
# [1295 rows x 4 columns]

# %%
# Keep only rows with non-negative prices and quantities
df_coffee = df_coffee[(df_coffee['price'] >= 0) & (df_coffee['Quantity'] >= 0)]

# Print the number of rows removed due to negative prices or quantities
print("\nNumber of rows removed due to negative prices or quantities:", len(negative_prices) + len(negative_quantities))
# Out:
# Number of rows removed due to negative prices or quantities: 1295

# %% [markdown]
# # Data Preparation

# %%
import matplotlib.pyplot as plt

# Data Preparation for DeepAR

# Calculate the sales by multiplying the quantity and price for each row
df_coffee['Sales'] = df_coffee['Quantity'] * df_coffee['price']

# Group the DataFrame by the date component of 'InvoiceDate', summing the 'Sales' for each day, and reset the index
daily_sales_article = df_coffee.groupby(['article', df_coffee['datetime'].dt.floor('D')])['Sales'].sum().reset_index()

# Display the daily sales data
print("Daily Sales Data:")
print(daily_sales_article)
# Out:
# Daily Sales Data:
#          article   datetime  Sales
# 0              . 2021-03-04    0.0
# 1              . 2021-03-18    0.0
# 2              . 2021-04-04    0.0
# 3              . 2021-04-27    0.0
# 4              . 2021-07-10    0.0
# ...          ...        ...    ...
# 29197  VIK BREAD 2022-09-18   27.0
# 29198  VIK BREAD 2022-09-23   24.3
# 29199  VIK BREAD 2022-09-24   27.0
# 29200  VIK BREAD 2022-09-25   27.0
# 29201  VIK BREAD 2022-09-30   32.4
#
# [29202 rows x 3 columns]

# %%
# Count the number of sales by product in the dataset
article_count = daily_sales_article['article'].nunique()

# Create a horizontal bar plot to visualize the number of sales by article
plt.figure(figsize=(14, 25))
ax = sns.countplot(data=daily_sales_article, y='article', hue='article', palette='viridis', order=daily_sales_article['article'].value_counts().index, legend=False)
plt.ylabel('Product Name')
plt.xlabel('# of Sales')
plt.title(f'Number of Unique products: {article_count}')

# Add count numbers next to the bars
for p in ax.patches:
    width = int(p.get_width())  # Convert width to integer
    plt.text(width + 1, p.get_y() + p.get_height() / 2., f'{width}', ha='left', va='center')

plt.show()

# %%
# Filter the DataFrame to include only the specified backeries
products = ['BANETTE', 'TRADITIONAL BAGUETTE', 'COUPE', 'CROISSANT']
selected_product_sales = daily_sales_article[daily_sales_article['article'].isin(products)]

# Create separate line plots for each product
for product in products:
    article_data = selected_product_sales[selected_product_sales['article'] == product]
    plt.figure(figsize=(14, 6))
    plt.plot(article_data['datetime'], article_data['Sales'], marker='o')
    plt.xlabel('Date')
    plt.ylabel('Sales')
    plt.title(f'Daily Sales in {products}')
    plt.grid(True)  # Add a grid for better readability
    plt.show()

# %% [markdown]
# # Data Preparation for DeepAR Model Training

# %%
# Create a label encoder instance and encode the 'article' column
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
daily_sales_article['article'] = label_encoder.fit_transform(daily_sales_article['article'])

# Create a dictionary to map the encoded numbers to their corresponding products
product_code_mapping = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))

# Print the mapping
print("Backery product Mapping:")
print(product_code_mapping)
# Out:
# Backery product Mapping:
# ...

# %%
# Plot the daily sales data with markers for each data point

# Create a new figure for the plot with a specified size
plt.figure(figsize=(16, 6))

# 'InvoiceDate' is on the x-axis, 'Sales' is on the y-axis
# Marker style is set to 'o' (circle), line color is set to blue, and line style is set to solid
plt.plot(daily_sales_article['datetime'], daily_sales_article['Sales'], marker='o', color='b', linestyle='-')

# Set the title of the plot
plt.title('Daily Sales')

# Set the label for the x-axis
plt.xlabel('Date')

# Set the label for the y-axis
plt.ylabel('Sales')

# Add gridlines to the plot
plt.grid(True)

# Display the plot
plt.show()

# %%
# Plot the daily sales data for the last week with markers for each data point

# Slice the daily_sales DataFrame to include only the last week's worth of data
last_week_sales = daily_sales_article.tail(7)

# Create a new figure for the plot with a specified size
plt.figure(figsize=(16, 6))

# 'InvoiceDate' is on the x-axis, 'Sales' is on the y-axis
# Marker style is set to 'o' (circle), line color is set to blue, and line style is set to solid
plt.plot(last_week_sales['datetime'], last_week_sales['Sales'], marker='o', color='b', linestyle='-')

# Set the title of the plot
plt.title('Daily Sales for the Last Week')

# Set the label for the x-axis
plt.xlabel('Date')

# Set the label for the y-axis
plt.ylabel('Sales')

# Add gridlines to the plot
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# From here we can see that the last week's sales has two significant spikes, which will compromise the regulation of the training pattern, and disrupt the result. Hence, I hereby plan to adjust the hyperparameter context_length to longer days (eg. dating back to January in 2022 where the sales pattern is visual and contains more data) in order to derive a more credible result and increase precision, adjustments will be made in the following session before training.

# %% [markdown]
# # Data Preparation for DeepAR Model Training

# %%
def convert_to_deepar_json(df, filename, is_test=False):
    grouped = df.groupby('article')
    time_series = []
    for _, group in grouped:
        # Create a record for each time series
        record = {
            "start": str(group['datetime'].min()),
            "target": group['Sales'].tolist(),
            "cat": [int(group['article'].iloc[0])]
        }
        if is_test:
            # For the test set, include only the last 'prediction_length' points
            record["target"] = record["target"][-prediction_length:]
        time_series.append(record)
    
    # Write the time series to a JSON Lines file
    with open(filename, 'w') as f:
        for ts in time_series:
            f.write(json.dumps(ts) + '\n')

# Set the prediction length
prediction_length = 7  # Adjust this value as needed

# Split the data into training and test sets
train_df = daily_sales_article.copy()
test_df = daily_sales_article.groupby('article').apply(lambda x: x.tail(prediction_length)).reset_index(drop=True)

# Ensure that the test set has the last 'prediction_length' points for each time series
test_df = test_df.groupby('article').filter(lambda x: len(x) == prediction_length)

# Convert the training and test sets to DeepAR JSON format
convert_to_deepar_json(train_df, 'train_data.json')
convert_to_deepar_json(test_df, 'test_data.json', is_test=True)
# Out:
# /tmp/ipykernel_7812/2453984005.py:26: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_df = daily_sales_article.groupby('article').apply(lambda x: x.tail(prediction_length)).reset_index(drop=True)

# %% [markdown]
# # SageMaker Session and Environment Setup

# %%
# Create a SageMaker session for managing interactions with the SageMaker environment
sagemaker_session = sagemaker.Session()

# Retrieve the execution role for the current SageMaker notebook instance
role = get_execution_role()

# Retrieve the AWS region name from the SageMaker session
region = sagemaker_session.boto_region_name

# Specify the DeepAR container
image_uri = retrieve('forecasting-deepar', region)

# Define the default Amazon S3 bucket for the SageMaker session
bucket = sagemaker_session.default_bucket()

# Define the prefix for the S3 key where data will be stored
prefix = 'sagemaker/onlineretail/basic-prediction'

# Define the path to the local training data file
local_train = 'train_data.json'

# Define the path to the local validation data file
local_validation = 'test_data.json'

# Upload the local training data file to the specified S3 bucket and prefix, returning the S3 URI
train_uri = sagemaker_session.upload_data(local_train, bucket=bucket, key_prefix=prefix)

# Upload the local validation data file to the specified S3 bucket and prefix, returning the S3 URI
test_uri = sagemaker_session.upload_data(local_validation, bucket=bucket, key_prefix=prefix)

# Print the execution role ARN to the console
print("Execution Role ARN:", role)

# Print the AWS region name to the console
print("AWS Region:", region)

# Print the S3 URI for the training data to the console
print("Training Data S3 URI:", train_uri)

# Print the S3 URI for the validation data to the console
print("Validation Data S3 URI:", test_uri)
# Out:
# Execution Role ARN: arn:aws:iam::695818212408:role/LabRole
# AWS Region: us-east-1
# Training Data S3 URI: s3://sagemaker-us-east-1-695818212408/sagemaker/onlineretail/basic-prediction/train_data.json
# Validation Data S3 URI: s3://sagemaker-us-east-1-695818212408/sagemaker/onlineretail/basic-prediction/test_data.json

# %% [markdown]
# # Hyperparameter Tuning
# Within the code, some crucial hyperparameters determine the model’s behaviour and the model’s predictive performance. The (context_length) specifies the length of the context used for training, and I changed from 30 days to 120 dayes because the spike sales in the last week will affect the training. Epochs specify the number of training epochs. To minimize RMSE on the validation set, and I changed from 20 to 11. We will perform hyperparameter tuning to investigate the most optimal dimensions of each hyperparameter.

# %% [markdown]
# # Estimator Configuration for DeepAR Algorithm Training

# %%
from sagemaker.estimator import Estimator

# Define an Estimator for the DeepAR algorithm in SageMaker
deepar_estimator = Estimator(
    sagemaker_session=sagemaker_session,  # Specify the SageMaker session
    image_uri=image_uri,  # Specify the container image URI for the DeepAR algorithm
    role=role,  # Specify the IAM role ARN used by SageMaker
    instance_count=1,  # Specify the number of instances to use for training
    instance_type='ml.m5.large',  # Specify the instance type for training
    output_path='s3://{}/output'.format(bucket),  # Specify the S3 location for saving the model artifacts and output
    base_job_name='coffee-deepar-forecasting'  # Specify the base job name for the training job
)

# Set hyperparameters for the DeepAR algorithm
deepar_estimator.set_hyperparameters(
    time_freq='D',  # Specify the time frequency of the data (e.g., 'D' for daily)
    context_length=120,  # Specify the length of the context used for training (e.g., 30 days)
    prediction_length=7,  # Specify the length of the prediction horizon (forecasting 7 days into the future)
    epochs=11,  # Specify the number of training epochs
    early_stopping_patience=10,  # Specify the number of epochs with no improvement before early stopping
    num_dynamic_feat='auto',  # Automatically detect dynamic features (if any)
    cardinality='auto'  # Automatically detect the cardinality of categorical features (if any)
)

# %% [markdown]
# # Model Training with DeepAR Estimator
# This training objective requires Deep AR to forecast sales figures using provided input cues. By utilizing the model's predictive abilities, Presotea can efficiently allocate resources to optimize product and material usage, effectively tackling the primary challenge of declining revenue. Pinpointing the main contributor enables Presotea to prioritize products with the greatest profit potential.

# %%
# Define data channels for training the DeepAR estimator, mapping 'train' and 'test' keys to the S3 URIs of the training and test data
data_channels = {
    'train': train_uri,
    'test': test_uri
}

# Fit the DeepAR estimator using the specified data channels
deepar_estimator.fit(inputs=data_channels)
# Out:
# INFO:sagemaker:Creating training-job with name: coffee-deepar-forecasting-2024-04-07-16-44-49-416
# 2024-04-07 16:44:49 Starting - Starting the training job...
# 2024-04-07 16:45:05 Starting - Preparing the instances for training...
# 2024-04-07 16:45:36 Downloading - Downloading input data...
# 2024-04-07 16:46:06 Downloading - Downloading the training image..................
# 2024-04-07 16:49:02 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Running custom environment configuration script
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# ...

# %% [markdown]
# # Model Deployment to SageMaker Endpoint

# %%
# Specify the endpoint name
endpoint_name = 'coffee-endpoint-basic'

# Specify the endpoint configuration name
endpoint_config_name = 'coffee-endpoint-basic'

# Create a SageMaker client
sagemaker_client = boto3.client('sagemaker')

# %%
# Check if the endpoint configuration already exists
try:
    sagemaker_client.describe_endpoint_config(EndpointConfigName=endpoint_config_name)
    print(f'Endpoint configuration "{endpoint_config_name}" already exists. Deleting...')
    sagemaker_client.delete_endpoint_config(EndpointConfigName=endpoint_config_name)
    print(f'Endpoint configuration "{endpoint_config_name}" deleted.')
except ClientError as e:
    if e.response['Error']['Code'] == 'ValidationException':
        print(f'Endpoint configuration "{endpoint_config_name}" does not exist.')
# Out:
# Endpoint configuration "coffee-endpoint-basic" does not exist.

# %%
# Check if the endpoint already exists
try:
    sagemaker_client.describe_endpoint(EndpointName=endpoint_name)
    print(f'Endpoint "{endpoint_name}" already exists. Deleting...')
    sagemaker_client.delete_endpoint(EndpointName=endpoint_name)
    print(f'Endpoint "{endpoint_name}" deleted.')
except ClientError as e:
    if e.response['Error']['Code'] == 'ValidationException':
        print(f'Endpoint "{endpoint_name}" does not exist.')
    else:
        raise
# Out:
# Endpoint "coffee-endpoint-basic" does not exist.

# %%
# Deploy the trained model to an endpoint
predictor = deepar_estimator.deploy(
    initial_instance_count=1,  # Specify the initial number of instances for the endpoint
    instance_type='ml.m5.large',  # Specify the instance type for the endpoint
    serializer=sagemaker.serializers.JSONSerializer(),  # Specify the serializer for the input data
    deserializer=sagemaker.deserializers.JSONDeserializer(),  # Specify the deserializer for the output data
    endpoint_name=endpoint_name,  # Specify the name of the endpoint
)

# Print the endpoint name and endpoint configuration name
print(f'Endpoint name: {predictor.endpoint_name}')
print(f'Endpoint configuration name: {endpoint_config_name}')
# Out:
# INFO:sagemaker:Creating model with name: coffee-deepar-forecasting-2024-04-07-17-18-21-529
# INFO:sagemaker:Creating endpoint-config with name coffee-endpoint-basic
# INFO:sagemaker:Creating endpoint with name coffee-endpoint-basic
# ---------!Endpoint name: coffee-endpoint-basic
# Endpoint configuration name: coffee-endpoint-basic

# %%
# Display the country code list
print("Product List:")
for product, code in product_code_mapping.items():
    print(f"{product}: {code}")

# Prompt for the country code
selected_product_code = int(input("Enter the product code for prediction: "))

# Find the product name corresponding to the selected country code
selected_product_name = [product for product, code in product_code_mapping.items() if code == selected_product_code][0]

# Prepare the input data for prediction
# 'daily_sales_country' DataFrame contains the historical sales data for all countries
selected_product_sales = daily_sales_article[daily_sales_article['article'] == selected_product_code]  # Filter for selected country

selected_product_sales.tail()

last_date = selected_product_sales['datetime'].max().strftime('%Y-%m-%d')  # Get the last date of sales for the selected country
prediction_input = {
    "instances": [{"start": "2022-09-01", "target": selected_product_sales['Sales'].tolist(), "cat": [selected_product_code]}],
    "configuration": {"num_samples": 100, "output_types": ["mean", "quantiles"], "quantiles": ["0.1", "0.9"]}
}

# Invoke the endpoint for prediction
sagemaker_runtime = boto3.client('sagemaker-runtime')
response = sagemaker_runtime.invoke_endpoint(
    EndpointName=endpoint_name,
    ContentType='application/json',
    Body=json.dumps(prediction_input)
)

# Parse the prediction response
predictions = json.loads(response['Body'].read().decode())
predicted_means = predictions['predictions'][0]['mean']
predicted_quantiles = predictions['predictions'][0]['quantiles']
predicted_lower_quantile = predicted_quantiles['0.1']
predicted_upper_quantile = predicted_quantiles['0.9']

# Create a DataFrame for the predicted sales
predicted_dates = pd.date_range(start='2022-09-01', periods=len(predicted_means), freq='D')
predicted_sales = pd.DataFrame({'Date': predicted_dates, 'Predicted Sales': predicted_means})

# Display the predicted sales
print(predicted_sales)

# Filter the historical data to include only the last 30 days for the selected country
last_30_days_sales = selected_product_sales[selected_product_sales['datetime'] >= (selected_product_sales['datetime'].max() - pd.Timedelta(days=30))]

# Plot the daily sales for the last 30 days for the selected country
plt.figure(figsize=(16, 6))
plt.plot(last_30_days_sales['datetime'], last_30_days_sales['Sales'], marker='o', linestyle='-', label=f'Historical Sales ({selected_product_name})')

# Plot the predicted mean sales
plt.plot(predicted_dates, predicted_means, label='Predicted Mean Sales')

# Plot the predicted quantiles as a shaded area
plt.fill_between(predicted_dates, predicted_lower_quantile, predicted_upper_quantile, color='gray', alpha=0.5, label='Predicted 80% Confidence Interval')

# Add labels and title
plt.title(f'Daily Sales with Prediction for September 1st Onwards ({selected_product_name})')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# Product List:
# .: 0
# 12 MACARON: 1
# ARMORICAIN: 2
# ARTICLE 295: 3
# BAGUETTE: 4
# BAGUETTE APERO: 5
# BAGUETTE GRAINE: 6
# BANETTE: 7
# BANETTINE: 8
# BOISSON 33CL: 9
# BOTTEREAU: 10
# BOULE 200G: 11
# BOULE 400G: 12
# BOULE POLKA: 13
# BRIOCHE: 14
# BRIOCHE DE NOEL: 15
# BRIOCHETTE: 16
# BROWNIES: 17
# BUCHE 4PERS: 18
# BUCHE 6PERS: 19
# BUCHE 8PERS: 20
# CAFE OU EAU: 21
# CAKE: 22
# CAMPAGNE: 23
# CARAMEL NOIX: 24
# CEREAL BAGUETTE: 25
# CHAUSSON AUX POMMES: 26
# CHOCOLAT: 27
# CHOU CHANTILLY: 28
# COMPLET: 29
# COOKIE: 30
# COUPE: 31
# CROISSANT: 32
# CROISSANT AMANDES: 33
# CRUMBLE: 34
# CRUMBLECARAMEL OU PISTAE: 35
# DELICETROPICAL: 36
# DEMI BAGUETTE: 37
# DEMI PAIN: 38
# DIVERS BOISSONS: 39
# DIVERS BOULANGERIE: 40
# DIVERS CONFISERIE: 41
# DIVERS PATISSERIE: 42
# DIVERS SANDWICHS: 43
# DIVERS VIENNOISERIE: 44
# DOUCEUR D HIVER: 45
# ECLAIR: 46
# ECLAIR FRAISE PISTACHE: 47
# ENTREMETS: 48
# FICELLE: 49
# FINANCIER: 50
# FINANCIER X5: 51
# FLAN: 52
# FLAN ABRICOT: 53
# ...

# %% [markdown]
# # Delete the Endpoint and Endpoint Config

# %%
# Prompt for confirmation before deleting the endpoint and endpoint configuration
confirmation = input("Are you sure you want to delete the endpoint and endpoint configuration? (yes/no): ")

if confirmation.lower() == 'yes':
    # Check if the endpoint configuration already exists
    try:
        sagemaker_client.describe_endpoint_config(EndpointConfigName=endpoint_config_name)
        print(f'Endpoint configuration "{endpoint_config_name}" already exists. Deleting...')
        sagemaker_client.delete_endpoint_config(EndpointConfigName=endpoint_config_name)
        print(f'Endpoint configuration "{endpoint_config_name}" deleted.')
    except ClientError as e:
        if e.response['Error']['Code'] == 'ValidationException':
            print(f'Endpoint configuration "{endpoint_config_name}" does not exist.')
        else:
            raise

    # Check if the endpoint already exists
    try:
        sagemaker_client.describe_endpoint(EndpointName=endpoint_name)
        print(f'Endpoint "{endpoint_name}" already exists. Deleting...')
        sagemaker_client.delete_endpoint(EndpointName=endpoint_name)
        print(f'Endpoint "{endpoint_name}" deleted.')
    except ClientError as e:
        if e.response['Error']['Code'] == 'ValidationException':
            print(f'Endpoint "{endpoint_name}" does not exist.')
        else:
            raise
else:
    print("Deletion cancelled.")

# %% [markdown]
# # Development Costs
# ![image.png](attachment:a87889e9-0c4c-46c6-8399-18d086799e8b.png)

# %% [markdown]
# # Business Changes  -- Deep AR adoption plan
# Project name: Presotea’s shift to time series analysis with Deep AR
#
# Project timeline:  30 days
#
# Eliminate redundant steps: Presotea used to struggle with manual modeling and data retrospection -- habitually on paper work and Excel spreadsheet -- that results in a lot of man hours. Nevertheless, they have a hard time capturing relationships between different time series, such as cannibalization between different flavors which causes erroneous prediction, and indulging gut-driven decisions. Deep AR resolves these problems by recurrent neural network with an LSTM foundation that has been trained using all of the time series' historical data. It cuts off redundant, manual steps and significantly saves costs.(Maklin, 2022)
#
# Introducing new tasks:
# 1.A dashboard resembling agile project management will be put in place to record,monitor and calibrate daily performance, deviation from the trajectory, and progress.
# 2.In terms of hardware, Presotea will equip every refrigerator with a real-time stock monitor, which possesses and updates stock information by sync. Monitors will connect to Presotea’s database.
#
#
# # Development Timeline
# # Fixed time investments
#
# Employee Training: For a total of 15 hours (spanning across two weeks), four Presotea employees will receive basic technical training on AWS's context in order to gain the abilities necessary to comprehend, analyse, and utilise Deep AR insights using EC2 instances and Sagemaker.
#
# Agile project management initiation and MVP: Building the dashboard and stakeholders onboarding, meeting and decision-making will be about one week.
#
# Data scientist: A contracted data engineer will devote a total of 23 hours (2 weeks) to the technical advancement, including:
#
# Week 1
# The data scientist will familiarize themselves with Presotea’s information and dive into the industry’s business canva, including stakeholders, resources, activities,channels, customer relationships, segments, and cost/profit structure in order to derive and filter relevant industry data for training.  (3 hours)
# Data Preparation and Formatting: The data scientist will collaborate with the manager to prepare and format the store's historical sales data and other store’s data as a training set for input into Deep AR, ensuring it meets the algorithm's requirements. (6 hours)
# Build the model through SageMaker and configure and deploy the model on an EC2 instance. (2 hours)
#
# Week 2
# Launch the training job: Train the Deep AR model using the formatted data and fine-tune the hyperparameters to optimize forecasting performance.(6 hours)
# Employee training: Educate Presotea staff members on how to anticipate sales using the final Deep AR model through training sessions. This includes exploring and exploiting model outputs, analysing findings, and offering suggestions for using forecasting procedures.(6 hours)
#
# Week 3
# Data Engineer
# Hardware onload: Provide mechanisms(compatible scanner connected to databank) for planned or real-time data or stock information to every refrigeration system, to streamline meticulous, transparent and logical data synchronization, and ensure that the model is always up to date. (5 hours)
#
# # Variable Time Investments
#
# Model Training with AWS Sagemaker(15 hours): Training the model using SageMaker and Deep AR may involve configuring the model, setting hyperparameters, launching the training job, and the trimming and selection of the optimal time series interval (need multiple attempts and empirical iterations). The training process takes about 15 hours.
#
# Data Processing and Preparation (1 week):The time required for investigation of the market trend, quantitative analysis on Presotea’s demographics and the store’s position, data collection and preparation could be 1 week.

# %% [markdown]
# # Cost-Benefit Analysis
#
# ![image.png](attachment:ff131a28-e58f-43fd-ac40-29ec6fc8a65d.png)
#
#
# # Project cost
# Total cost = fixed cost + variable cost = ($3,600+$400+$2017.96+ $2,000)+($1.725+$0.75+$0.92+$4+$0.05) = $8,025.405 (the first month)
#
# # Projected Cash Flow
# The revenue of Presotea after the adoption of the Deep AR algorithm will be projected to raise by $1,500 per month.
#
#
# # Intangible benefit - customer loyalty, WOM( world of mouth)
# By maintaining regular product availability, Presotea can minimize waiting time and stockouts. This is made possible by effective forecasting. Presotea's ability to satisfy consumers' appetites boosts satisfaction and cultivates loyalty.
# Moreover, Deep AR produces more seamless operations, which are important generators of favourable word-of-mouth.Consumers find that Presotea's bubble tea meets their demands, and those who enjoy the company's goods and services recommend it to others. When they hear positive word-of-mouth, especially from someone they can trust, prospective consumers promise to use the business when they get the opportunity.(Rahi et al., 2021).
#
# # ROI & Break-even point
# 1-year ROI = (($1,500*12-($8017.96+$7.445*12)/$8,107.3) *100%= 122.02%
#
# Break-even point = $8,107.3/$1,500 = 5.4 months
#
#
# The break-even analysis suggests that it requires approximately 6 months to reach the break-even point. The ROI for the first year demonstrates robust profitability and signifies that the iterative time series analysis will yield sustained long-term sales growth thereafter.

# %% [markdown]
# # Change Management Plan
#
# # Stakeholder Engagement
# Management: The manager, who is also the project director, is held accountable for the technical revamping of Presotea. He will conduct stakeholder analysis, risk register, identify sponsors,plan budget, and push forward project charter before stakeholder onboarding. In a word, he should understand the plan’s prerequisites, risk and benefit, and the data ingestions by the predicted results and key successor.
#
# Sponsors: GPS at Queen’s University and Gangnam Style, who will be engaged early on.They provide financial support and elicit potential customers to Presotea through crossover campaigns.
#
# Employee: The strategy is linked to the efforts and abilities of four employees.They are in charge of completing the project, guaranteeing the calibre of the job, managing the growth of the Deep AR model, and becoming acquainted with technological capabilities.
#
# Data Scientist & Engineer: A bottleneck think tank that the management team should approach at first for first-hand data transfer, and communicate the goals and expectations to. Management should also inform the technical person of any subtle changes in the project.
#
# Marketing team:Changes should be communicated to the team, and management should grant the marketing team access to the store's marketing function block so that thorough plans may be created in advance.
#
#
# # Employee training (referenced COMM493 course syllabus)
# Four employees from Presotea will participate in essential technical training with a focus on AWS, where they will acquire the necessary skills to utilize machine learning insights through EC2 instances and Sagemaker. With the guidance of a technical expert, they will aim to comprehend and effectively communicate Deep AR's functions and basic operations. Subsequently, they will endeavor to train relevant datasets using Deep AR and fine-tune hyperparameters based on customer propensities and the store's dynamic KPIs. Following this, they will engage in a real-world business case seminar to prepare for a customer pilot program.
#
# 1.Introduction to AI and business case, AWS and building VPC, launching Web server (3 hours).
#
# 2.Basic machine learning with Sagemaker,utilize SageMaker for essential AI model development. (6 hours).
#
# 3.Training in Deep AR time series methods, methodologies, and preprocessing large, complicated datasets to optimise the model.(6 hours).
#
#
# # Monitoring and Feedback
# To ensure ongoing monitoring and agile feedback from end users (customers), Presotea plans to develop a dashboard as previously mentioned. This dashboard will feature visual representations of tasks on the user interface, along with quantitative analysis of services or products delivered during and after three nodes: stakeholder engagement, Deep AR development and marketing campaign. This will be achieved by launching blocks with minimal viable products to monitor the process.

# %% [markdown]
# # Marketing Plan
#
#
# Promotional strategy
#
# Influencer engagement: Presotea will invite local-based web influencers, including photographers,and individual baristars that possess prominent online presence, for pre-tasting and reviewing.They primarily document drinks and write about recipes, restaurant reviews via social platforms (Instagram, TikTok, Facebook, X).
#
#
# Promotional efforts -- “blind box” bundling service: Presotea will create a limited-time curated menu with mysterious “blind box” discounted products. Each box contains a drink and one pastry with unknown content. Blind box stimulates addictive behaviour and collecting habits among repeated customers -- especially students seeking peculiarity -- to realize small profits and quick return.
#
# # Pilot program
# Presotea plans to complete over 50 predictions for the next half a year’s sales, and compile them into detailed case studies to showcase customers how Deep AR helps Presotea recalibrate product focus, calculate economic outcomes and iterate throughout current profit formula. Presotea also plans to conduct a vote during the “showdown” session, where a variety of new released drinks will be produced by algorithm’s live iteration. Customers will vote for next season’s innovations.
#
# # Success metrics
# 1.Increase new customers by 20% within six months and increase visitation by 15%, with an average customer dwell time of no less than 10 minutes.
#
# 2.Monthly sales growth rate reaches 20%.
#
# 3.Adoption rate of “blind box” reaches over 50%.
# Customer repetition rate increases by 20%.

# %% [markdown]
# # References
#
#
# AWS. Deepar forecasting algorithm - amazon sagemaker. https://docs.aws.amazon.com/sagemaker/latest/dg/deepar.html
#
# Eby, K. (2022). How to streamline your work processes. Smartsheet. https://www.smartsheet.com/streamlining-processes#:~:text=In%20order%20to%20streamline%20a,evaluate%20handoffs%2C%20and%20identify%20bottlenecks
#
# Maklin, C. (2022). Deepar forecasting algorithm. Medium. https://medium.com/@corymaklin/deepar-forecasting-algorithm-6555efa63444
#
# Rahi, S., Ammara, U. E., & Qazi, T. F. (2021). Assessing (the impact) of advertisement on Customer Decision Making: Evidence from an educational institution. SSRN. https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3764088
#
# Šimek, V. (2022). 10 major retail problems and solutions [with real-world examples]. Inventoro. https://inventoro.com/retail-problems-and-solutions/
